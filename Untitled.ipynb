# %%
pip install streamlit
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    -------------- ------------------------- 3.4/9.7 MB 18.4 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.7 MB 10.8 MB/s eta 0:00:01
#    ------------------------ --------------- 6.0/9.7 MB 9.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.8/9.7 MB 8.2 MB/s eta 0:00:01
#    -------------------------------- ------- 7.9/9.7 MB 7.5 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.7 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.7 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 6.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    ---------------------------------------- 731.2/731.2 kB 5.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/25.3 MB ? eta -:--:--
# ...

# %%
import streamlit as st

# %%
import os
import pickle as pkl
try:
    import xgboost as xgb
    st.success("XGBoost is installed!")
except ModuleNotFoundError:
    st.error("XGBoost is missing. Please install it using 'pip install xgboost'.")
# Out:
# 2025-03-08 18:06:09.121 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-08 18:06:09.429
# ...
#   command:
#
#     streamlit run C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-03-08 18:06:09.431 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
if os.path.exists("best_xgb_2.pkl"):
    with open("best_xgb_2.pkl", "rb") as file:
        xgb = pkl.load(file)
else:
    st.error("Error: Model file 'best_xgb_2.pkl' not found!")

if os.path.exists("TD3_5.zip"):
    from stable_baselines3 import TD3
    td3_5 = TD3.load("TD3_5")
else:
    st.error("Error: Model file 'TD3_5' not found!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 3
#       1 if os.path.exists("best_xgb_2.pkl"):
#       2     with open("best_xgb_2.pkl", "rb") as file:
# ----> 3         xgb = pkl.load(file)
#       4 else:
#       5     st.error("Error: Model file 'best_xgb_2.pkl' not found!")
#
# ModuleNotFoundError: No module named 'xgboost'
