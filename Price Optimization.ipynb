# %%
import pandas as pd
import numpy as np
import pickle
from datetime import timedelta
from sklearn.preprocessing import OrdinalEncoder
import random

# %%
with open('C:/Users/shiro/OneDrive/Desktop/Final Project OG/best_xgb_2.pkl', 'rb') as file:
    xgb = pickle.load(file)

# %%
product = pd.read_excel('C:/Users/shiro/OneDrive/Desktop/Final Project OG/Dataset/Dataset.xlsx', sheet_name="dh Products Lookup")
store = pd.read_excel('C:/Users/shiro/OneDrive/Desktop/Final Project OG/Dataset/Dataset.xlsx', sheet_name="dh Store Lookup")
upc_encoding = pd.read_excel('C:/Users/shiro/OneDrive/Desktop/Final Project OG/Dataset/StoreID UPC Encoding.xlsx' , sheet_name='Product')
store_encoding = pd.read_excel('C:/Users/shiro/OneDrive/Desktop/Final Project OG/Dataset/StoreID UPC Encoding.xlsx', sheet_name='Store')
elasticity = pd.read_excel('C:/Users/shiro/OneDrive/Desktop/Final Project OG/Dataset/Price Elasticity.xlsx')
data = pd.read_excel('C:/Users/shiro/OneDrive/Desktop/Final Project OG/Dataset/FINAL SUBSET_preprocessed_dataOG.xlsx')

# %% [markdown]
# #### Functions to forecast unit sales

# %%
# Functions to forecast next week unit sales
def get_store_upc_data(store_id, upc):
    store_upc_data = data[(data['UPC'] == upc) & (data['STORE_ID'] == store_id)]
    return store_upc_data

# To pre-process user inputs for demand forecasting
def processing_pipeline(input_data):
  
    processed_input = input_data.copy()

    store_id = processed_input['STORE_ID'].iloc[0]
    upc = processed_input['UPC'].iloc[0]
    store_upc_data = get_store_upc_data(store_id, upc)
    store_upc_data = store_upc_data.sort_values(by='WEEK_END_DATE', ascending=False)

    # Get the next week date of last date using  timedelta(days=7) 
    processed_input['WEEK_END_DATE'] = store_upc_data['WEEK_END_DATE'].max() + timedelta(days=7) 

    # Extract YEAR and WEEK_NUM 
    processed_input['YEAR'] = processed_input['WEEK_END_DATE'].dt.year
    processed_input['WEEK_NUM'] = processed_input['WEEK_END_DATE'].dt.isocalendar().week

    # Frequecy encoding of STORE_ID
    processed_input = processed_input.merge(store_encoding, on='STORE_ID', how='left')
    # Frequecy encoding of UPC
    processed_input = processed_input.merge(upc_encoding, on='UPC', how='left')

    # Get SEG_VALUE_NAME based on STORE_ID
    processed_input = processed_input.merge(store[['STORE_ID', 'SEG_VALUE_NAME']], on='STORE_ID', how='left')

    # Ordinal encoding of SEG_VALUE_NAME
    encoder = OrdinalEncoder(categories=[['VALUE', 'MAINSTREAM', 'UPSCALE']]) 
    processed_input['SEG_VALUE_NAME_ORDINAL'] = encoder.fit_transform(processed_input[['SEG_VALUE_NAME']]).astype(int) 

    # Get SALES_AREA_SIZE_NUM based on STORE_ID
    processed_input = processed_input.merge(store[['STORE_ID', 'SALES_AREA_SIZE_NUM']], on='STORE_ID', how='left')

    # Get Category based on UPC 
    processed_input = processed_input.merge(product[['UPC', 'CATEGORY']], on='UPC', how='left')

    # One-hot encoding of CATEGORY
    product_categories = ['BAG SNACKS', 'COLD CEREAL', 'FROZEN PIZZA', 'ORAL HYGIENE PRODUCTS']
    for cat in product_categories:
        processed_input.loc[:,cat] = 0
    category = processed_input['CATEGORY']
    processed_input[category] = 1

    # Get UNIT_SALES_LOG_LAG1 and UNIT_SALES_LOG_LAG2
    last_data = store_upc_data.head(1)     # Get the last week of sales data (first row)
    last2_data = store_upc_data.iloc[[1]]  # Get the second last week of sales data (second row)
    processed_input['UNIT_SALES_LOG_LAG1'] = last_data['UNIT_SALES_LOG'].iloc[0]
    processed_input['UNIT_SALES_LOG_LAG2'] = last2_data['UNIT_SALES_LOG'].iloc[0]

    # Get the needed features for forecasting
    features = ['YEAR', 'WEEK_NUM', 'STORE_ID_COUNT', 'UPC_COUNT', 'UNIT_SALES_LOG_LAG1', 'UNIT_SALES_LOG_LAG2',
                'PRICE', 'FEATURE', 'DISPLAY', 'SEG_VALUE_NAME_ORDINAL', 'SALES_AREA_SIZE_NUM',
                'BAG SNACKS', 'COLD CEREAL', 'FROZEN PIZZA', 'ORAL HYGIENE PRODUCTS']

    return processed_input[features]

# To forecast demand based on user inputs
def predict(processed_input):
    y_pred = xgb.predict(processed_input)
    y_pred = np.exp(y_pred[0])
    pred_unit_sales = np.round(y_pred).astype(int)
    return pred_unit_sales

# %% [markdown]
# #### Data Preparation for Reinforcement Learning

# %%
data = pd.read_excel('C:/Users/shiro/OneDrive/Desktop/Final Project OG/Dataset/FINAL SUBSET_preprocessed_dataOG.xlsx')  
elasticity = pd.read_excel('C:/Users/shiro/OneDrive/Desktop/Final Project OG/Dataset/Price Elasticity.xlsx')
 
elasticity_copy = elasticity.copy()
elasticity_copy.drop(columns=['PRICE_ELASTICITY'], inplace=True)
elasticity_copy.rename(columns={'ABS_PRICE_ELASTICITY': 'PRICE_ELASTICITY'}, inplace=True)
elasticity_copy = elasticity_copy.sort_values(by=['STORE_ID', 'UPC'])

# Extract subset of stores for training - 3 stores
df2_subset = elasticity_copy[elasticity_copy['STORE_ID'].isin([2277, 15755, 25253])]  # 2277: UPSCALE, 15755: VALUES, 25253: MAINSTREAM
df2_subset['PRICE'] = np.nan
df2_subset.reset_index(inplace=True)
df2_subset.drop(columns=['index'], inplace=True)

# Generate random price within min and max price range for each store-upc combination
for i in range(len(df2_subset)):
    store_id = df2_subset['STORE_ID'].iloc[i]
    upc = df2_subset['UPC'].iloc[i]
    store_upc_data = get_store_upc_data(store_id, upc)  # Extract historical data for specific store and product
    min = store_upc_data['PRICE'].min()
    max = store_upc_data['PRICE'].max()
    random_price = random.uniform(min, max)    
    df2_subset.at[i,'PRICE'] = round(random_price, 2)
df3 = df2_subset.copy()
df3
# Out:
# C:\Users\shiro\AppData\Local\Temp\ipykernel_13360\2903307689.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_subset['PRICE'] = np.nan
# C:\Users\shiro\AppData\Local\Temp\ipykernel_13360\2903307689.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_subset.drop(columns=['index'], inplace=True)
#      STORE_ID          UPC  PRICE_ELASTICITY  PRICE
# 0        2277   1111009477          0.030736   1.31
# 1        2277   1111009497          0.004954   1.61
# 2        2277   1111009507          0.017499   1.35
# 3        2277   1111038078          0.092314   1.27
# 4        2277   1111038080          0.110819   2.31
# ..        ...          ...               ...    ...
# 106     25253  31254742735          0.014843   2.95
# 107     25253  31254742835          0.366440   3.88
# 108     25253  88491201426          0.667977   2.99
# 109     25253  88491201427          0.694300   2.57
# 110     25253  88491212971          0.058936   2.72
#
# [111 rows x 4 columns]

# %%
df3_00 = df3.copy()

df3_00['FEATURE'] = 0
df3_00['DISPLAY'] = 0
df3_00['FORECASTED_UNIT_SALES'] = np.nan

for i in range (len(df3_00)):
    store_upc_input = df3_00.iloc[[i]]
    processed_input = processing_pipeline(store_upc_input)
    pred_unit_sales = predict(processed_input)
    df3_00.at[i,'FORECASTED_UNIT_SALES'] = pred_unit_sales
df3_00
# Out:
#      STORE_ID          UPC  PRICE_ELASTICITY  PRICE  FEATURE  DISPLAY  \
# 0        2277   1111009477          0.030736   1.31        0        0
# 1        2277   1111009497          0.004954   1.61        0        0
# 2        2277   1111009507          0.017499   1.35        0        0
# 3        2277   1111038078          0.092314   1.27        0        0
# 4        2277   1111038080          0.110819   2.31        0        0
# ..        ...          ...               ...    ...      ...      ...
# 106     25253  31254742735          0.014843   2.95        0        0
# 107     25253  31254742835          0.366440   3.88        0        0
# 108     25253  88491201426          0.667977   2.99        0        0
# 109     25253  88491201427          0.694300   2.57        0        0
# 110     25253  88491212971          0.058936   2.72        0        0
#
#      FORECASTED_UNIT_SALES
# 0                    141.0
# 1                    117.0
# 2                     41.0
# 3                     10.0
# 4                     11.0
# ..                     ...
# 106                    3.0
# 107                    3.0
# 108                   22.0
# 109                   31.0
# 110                   17.0
#
# [111 rows x 7 columns]

# %%
df3_10 = df3.copy()

df3_10['FEATURE'] = 1
df3_10['DISPLAY'] = 0
df3_10['FORECASTED_UNIT_SALES'] = np.nan

for i in range (len(df3_10)):
    store_upc_input = df3_10.iloc[[i]]
    processed_input = processing_pipeline(store_upc_input)
    pred_unit_sales = predict(processed_input)
    df3_10.at[i,'FORECASTED_UNIT_SALES'] = pred_unit_sales
df3_10
# Out:
#      STORE_ID          UPC  PRICE_ELASTICITY  PRICE  FEATURE  DISPLAY  \
# 0        2277   1111009477          0.030736   1.31        1        0
# 1        2277   1111009497          0.004954   1.61        1        0
# 2        2277   1111009507          0.017499   1.35        1        0
# 3        2277   1111038078          0.092314   1.27        1        0
# 4        2277   1111038080          0.110819   2.31        1        0
# ..        ...          ...               ...    ...      ...      ...
# 106     25253  31254742735          0.014843   2.95        1        0
# 107     25253  31254742835          0.366440   3.88        1        0
# 108     25253  88491201426          0.667977   2.99        1        0
# 109     25253  88491201427          0.694300   2.57        1        0
# 110     25253  88491212971          0.058936   2.72        1        0
#
#      FORECASTED_UNIT_SALES
# 0                    149.0
# 1                     85.0
# 2                     44.0
# 3                     19.0
# 4                     20.0
# ..                     ...
# 106                    5.0
# 107                    4.0
# 108                   38.0
# 109                   49.0
# 110                   29.0
#
# [111 rows x 7 columns]

# %%
df3_01 = df3.copy()

df3_01['FEATURE'] = 0
df3_01['DISPLAY'] = 1
df3_01['FORECASTED_UNIT_SALES'] = np.nan

for i in range (len(df3_01)):
    store_upc_input = df3_01.iloc[[i]]
    processed_input = processing_pipeline(store_upc_input)
    pred_unit_sales = predict(processed_input)
    df3_01.at[i,'FORECASTED_UNIT_SALES'] = pred_unit_sales
df3_01
# Out:
#      STORE_ID          UPC  PRICE_ELASTICITY  PRICE  FEATURE  DISPLAY  \
# 0        2277   1111009477          0.030736   1.31        0        1
# 1        2277   1111009497          0.004954   1.61        0        1
# 2        2277   1111009507          0.017499   1.35        0        1
# 3        2277   1111038078          0.092314   1.27        0        1
# 4        2277   1111038080          0.110819   2.31        0        1
# ..        ...          ...               ...    ...      ...      ...
# 106     25253  31254742735          0.014843   2.95        0        1
# 107     25253  31254742835          0.366440   3.88        0        1
# 108     25253  88491201426          0.667977   2.99        0        1
# 109     25253  88491201427          0.694300   2.57        0        1
# 110     25253  88491212971          0.058936   2.72        0        1
#
#      FORECASTED_UNIT_SALES
# 0                    177.0
# 1                    136.0
# 2                     47.0
# 3                     13.0
# 4                     12.0
# ..                     ...
# 106                    4.0
# 107                    3.0
# 108                   26.0
# 109                   41.0
# 110                   19.0
#
# [111 rows x 7 columns]

# %%
df3_11 = df3.copy()

df3_11['FEATURE'] = 1
df3_11['DISPLAY'] = 1
df3_11['FORECASTED_UNIT_SALES'] = np.nan

for i in range (len(df3_11)):
    store_upc_input = df3_11.iloc[[i]]
    processed_input = processing_pipeline(store_upc_input)
    pred_unit_sales = predict(processed_input)
    df3_11.at[i,'FORECASTED_UNIT_SALES'] = pred_unit_sales
df3_11
# Out:
#      STORE_ID          UPC  PRICE_ELASTICITY  PRICE  FEATURE  DISPLAY  \
# 0        2277   1111009477          0.030736   1.31        1        1
# 1        2277   1111009497          0.004954   1.61        1        1
# 2        2277   1111009507          0.017499   1.35        1        1
# 3        2277   1111038078          0.092314   1.27        1        1
# 4        2277   1111038080          0.110819   2.31        1        1
# ..        ...          ...               ...    ...      ...      ...
# 106     25253  31254742735          0.014843   2.95        1        1
# 107     25253  31254742835          0.366440   3.88        1        1
# 108     25253  88491201426          0.667977   2.99        1        1
# 109     25253  88491201427          0.694300   2.57        1        1
# 110     25253  88491212971          0.058936   2.72        1        1
#
#      FORECASTED_UNIT_SALES
# 0                    226.0
# 1                    108.0
# 2                     62.0
# 3                     24.0
# 4                     21.0
# ..                     ...
# 106                    6.0
# 107                    5.0
# 108                   51.0
# 109                   62.0
# 110                   36.0
#
# [111 rows x 7 columns]

# %%
df3_expanded = pd.DataFrame()

for i in range (len(df3_00)):
    df3_expanded = pd.concat([df3_expanded, df3_00.iloc[i].to_frame().T], ignore_index=True)
    df3_expanded = pd.concat([df3_expanded, df3_10.iloc[i].to_frame().T], ignore_index=True)
    df3_expanded = pd.concat([df3_expanded, df3_01.iloc[i].to_frame().T], ignore_index=True)
    df3_expanded = pd.concat([df3_expanded, df3_11.iloc[i].to_frame().T], ignore_index=True)

cols = ['STORE_ID', 'UPC', 'FEATURE', 'DISPLAY', 'FORECASTED_UNIT_SALES']
df3_expanded[cols] = df3_expanded[cols].astype('int64')
df3_expanded.to_excel('C:/Users/shiro/OneDrive/Desktop/Final Project OG/Dataset/Subset Data Random Price Optimization.xlsx', index=False)

# %%
subset = pd.read_excel('C:/Users/shiro/OneDrive/Desktop/Final Project OG/Dataset/Subset Data Random Price Optimization.xlsx')
subset
# Out:
#      STORE_ID          UPC  PRICE_ELASTICITY  PRICE  FEATURE  DISPLAY  \
# 0        2277   1111009477          0.030736   1.31        0        0
# 1        2277   1111009477          0.030736   1.31        1        0
# 2        2277   1111009477          0.030736   1.31        0        1
# 3        2277   1111009477          0.030736   1.31        1        1
# 4        2277   1111009497          0.004954   1.61        0        0
# ..        ...          ...               ...    ...      ...      ...
# 439     25253  88491201427          0.694300   2.57        1        1
# 440     25253  88491212971          0.058936   2.72        0        0
# 441     25253  88491212971          0.058936   2.72        1        0
# 442     25253  88491212971          0.058936   2.72        0        1
# 443     25253  88491212971          0.058936   2.72        1        1
#
#      FORECASTED_UNIT_SALES
# 0                      141
# 1                      149
# 2                      177
# 3                      226
# 4                      117
# ..                     ...
# 439                     62
# 440                     17
# 441                     29
# 442                     19
# 443                     36
#
# [444 rows x 7 columns]

# %%
# Create dictionary to map STORE_ID and UPC to index.
# To simplify representation of STORE_ID and UPC for TD3 learning bcs current values are random number

upc_to_idx = {upc: idx for idx, upc in enumerate(subset['UPC'].unique())}
store_id_to_idx = {store_id: idx for idx, store_id in enumerate(subset['STORE_ID'].unique())}

def get_idx_store_id(store_id):
    store_id_idx = store_id_to_idx.get(store_id, -1)
    return store_id_idx 

def get_idx_upc(upc):
    upc_idx = upc_to_idx.get(upc, -1)
    return upc_idx 

def get_store_id_by_idx(idx):
    for key, value in store_id_to_idx.items():
        if value == idx:
            return key
    return 'STORE ID not found'

def get_upc_by_idx(idx):
    for key, value in upc_to_idx.items():
        if value == idx:
            return key
    return 'UPC not found'

# print(get_idx_store_id(25253))
# print(get_idx_upc(7192100337))
print(upc_to_idx)
print(store_id_to_idx)
# Out:
# {1111009477: 0, 1111009497: 1, 1111009507: 2, 1111038078: 3, 1111038080: 4, 1111085319: 5, 1111085345: 6, 1111085350: 7, 1111087395: 8, 1111087396: 9, 1111087398: 10, 1600027527: 11, 1600027528: 12, 1600027564: 13, 2840004768: 14, 2840004770: 15, 3000006340: 16, 3000006560: 17, 3000006610: 18, 3700031613: 19, 3700044982: 20, 3800031829: 21, 3800031838: 22, 3800039118: 23, 7192100336: 24, 7192100337: 25, 7192100339: 26, 7218063052: 27, 7797502248: 28, 7797508004: 29, 7797508006: 30, 31254742725: 31, 31254742735: 32, 31254742835: 33, 88491201426: 34, 88491201427: 35, 88491212971: 36}
# {2277: 0, 15755: 1, 25253: 2}

# %% [markdown]
# #### Custom Environment Setup

# %%
import gymnasium as gym
from gymnasium.spaces import Discrete, Box, Dict

# %%
class OptimalPricingEnv(gym.Env):    # pass gym.Env to OptimalPricingEnv class to inherit properties and methods from Env
    def __init__(self, dataset, n_stores, n_upcs, timesteps_per_episode):
        super(OptimalPricingEnv, self).__init__()
        
        # Define action space (price)
        self.action_space = Box(low=0.00, high=1.00, shape=(1,), dtype=np.float32)   
        # Define observation/state space 
        self.observation_space = Dict({
            'store_id': Discrete(n_stores),                                           
            'upc': Discrete(n_upcs),                                                  
            'feature': Discrete(2),                                                    
            'display': Discrete(2),                                                    
            'elasticity': Box(low=0.00, high=8.00, shape=(1,), dtype=np.float32),      
            'forecasted_unit_sales': Box(low=1, high=300, shape=(1,), dtype=np.int32) 
        })
        # print(self.action_space)
        # print(self.observation_space)

        # Initialize parameters
        self.dataset = dataset    
        self.dataset_idx = 0           # Index to keep track of the current episode (store-upc)
        self.timesteps_per_episode = timesteps_per_episode 
        self.episode_num = 0
        self.episode_info = []

    
    def reset(self, seed=None):
        self.episode_num += 1
        self.step_count = 0      # Counter to keep track number of steps within an episode
        self.terminated = False  # If True, reset() will be called
       
        # Extract current episode state from dataset
        self.current_eps = self.dataset.iloc[self.dataset_idx]

        # Format observation space 
        store_id_idx = get_idx_store_id(int(self.current_eps["STORE_ID"]))
        upc_idx =  get_idx_upc(int(self.current_eps["UPC"]))
        self.state = {
            'store_id': store_id_idx,
            'upc': upc_idx,
            'feature': int(self.current_eps["FEATURE"]),
            'display': int(self.current_eps['DISPLAY']),
            'elasticity': np.array([np.float32(self.current_eps["PRICE_ELASTICITY"])]),        
            'forecasted_unit_sales': np.array([np.int32(self.current_eps["FORECASTED_UNIT_SALES"])])  
        }

        self.dataset_idx = (self.dataset_idx + 1) % len(self.dataset)  # Loop over the dataset

        self.current_price = np.float32(self.current_eps["PRICE"])
        self.current_unit_sales = self.current_eps["FORECASTED_UNIT_SALES"]
        self.current_revenue = self.current_price * self.current_unit_sales
        self.price_min_bound = self.current_price * 0.8
        self.price_max_bound = self.current_price * 1.2
       
        info = {
            'current_price': self.current_price,
            'current_unit_sales': self.current_unit_sales,
            'current_revenue': self.current_revenue,
            'min_price_bound':self.price_min_bound,
            'max_price_bound': self.price_max_bound,
        }
        self.episode_info.append(info)
        return self.state, {}
    

    def step(self, action): 
        self.step_count += 1
        normalized_price = action[0]
        range = self.price_max_bound - self.price_min_bound
        new_price = (normalized_price * range) + self.price_min_bound
        new_price = np.round(new_price, 2)  
        
        # Apply action - Get the forecasted unit sales based on new price
        new_unit_sales = self.predict_unit_sales(new_price)
        # Get reward from environment in response to new price
        self.reward, new_revenue, price_changes_pct = self.get_reward(new_price, new_unit_sales)

        info = {
            'step': self.step_count,
            'state': self.state,
            'new_price': new_price,
            'price_changes':np.round(price_changes_pct, 2),
            'new_unit_sales': new_unit_sales,
            'new_revenue': np.round(new_revenue, 2),
            'reward': self.reward
        }
        self.episode_info.append(info)

        if self.step_count >= self.timesteps_per_episode:
            self.terminated = True   # when True, reset() will be called upon this function returns 
        else:
            self.state, _ = self.get_next_state(new_unit_sales)
 
        return self.state, self.reward, self.terminated, False, {}   # Return observation, reward, terminated, truncated, info
    

    def get_next_state(self, new_unit_sales): 
        self.next_state = {
            'store_id': self.state['store_id'],
            'upc': self.state['upc'],
            'feature': self.state['feature'],  
            'display': self.state['display'], 
            'elasticity': self.state['elasticity'],
            'forecasted_unit_sales': np.array([np.int32(new_unit_sales)])
        }
        return self.next_state, {}
    

    def predict_unit_sales(self, new_price):
        store_id = get_store_id_by_idx(self.state['store_id'])
        upc = get_upc_by_idx(self.state['upc'])

        state_input = []
        state_input.append({
                'STORE_ID': store_id,
                'UPC': upc,
                'PRICE': new_price,
                'FEATURE': self.state['feature'],
                'DISPLAY': self.state['display']})
        state_input = pd.DataFrame(state_input)
        processed_input = processing_pipeline(state_input)
        pred_unit_sales = predict(processed_input)
        return pred_unit_sales
    

    def get_reward(self, new_price, new_unit_sales):
        new_revenue = new_price * new_unit_sales
        relative_revenue_improvement = (new_revenue - self.current_revenue) / self.current_revenue
        price_changes_pct = (new_price - self.current_price) / self.current_price

        # Penalize price actions out of min and max bound
        penalty_value = 0
        if new_price < self.price_min_bound or new_price > self.price_max_bound:
            if price_changes_pct > 0.2 and price_changes_pct < 0.4:
                penalty_value = -0.1
            else: 
                penalty_value = -0.2
        reward = relative_revenue_improvement + penalty_value
        return reward, new_revenue, price_changes_pct

# %%
n_stores = subset['STORE_ID'].nunique()
n_upcs = subset['UPC'].nunique()
timesteps_per_episode = 150
n_episode = len(subset)
total_timesteps = timesteps_per_episode * n_episode

print('Num of unique STORE_ID: ', n_stores)
print('Num of unique UPC: ', n_upcs)
print('Timesteps per Episode: ', timesteps_per_episode)
print('Num of Episode (Len of Training Data): ', n_episode)
print('Total Timesteps: ', total_timesteps)
# Out:
# Num of unique STORE_ID:  3
# Num of unique UPC:  37
# Timesteps per Episode:  150
# Num of Episode (Len of Training Data):  444
# Total Timesteps:  66600

# %% [markdown]
# #### TD3 (Twin Delayed Deep Deterministic Policy Gradient)

# %%
from stable_baselines3 import TD3
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.evaluation import evaluate_policy
# Out:
# WARNING:tensorflow:From C:\Users\shiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Check environment setup to ensure it's compatible with the model API
from stable_baselines3.common.env_checker import check_env
env = OptimalPricingEnv(subset, n_stores, n_upcs, timesteps_per_episode)
check_env(env)
# Out:
# C:\Users\shiro\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\env_checker.py:462: UserWarning: We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) cf. https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html
#   warnings.warn(

# %% [markdown]
# ##### Training TD3

# %%
# Define directory path to save tensorboard
import os
log_path = os.path.join('RL_Training', 'Logs')
training_log_path = os.path.join(log_path, 'TD3_5')
os.makedirs(training_log_path, exist_ok=True)

# %%
# Initialize environment
env = OptimalPricingEnv(subset, n_stores, n_upcs, timesteps_per_episode)

# Define action noise for exploration
action_noise = NormalActionNoise(mean=np.zeros(env.action_space.shape), sigma=0.5)

# Initialize model/agent to learn
model = TD3('MultiInputPolicy', env, action_noise=action_noise, verbose=1, seed=42, tensorboard_log=training_log_path)

# Train model
model.learn(total_timesteps=total_timesteps) 

# Save model
model.save("TD3_5")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to RL_Training\Logs\TD3_5\TD3_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 11.5     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 29       |
# |    time_elapsed    | 20       |
# |    total_timesteps | 600      |
# | train/             |          |
# |    actor_loss      | 0.391    |
# |    critic_loss     | 0.00575  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 47.1     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 27       |
# |    time_elapsed    | 44       |
# |    total_timesteps | 1200     |
# | train/             |          |
# |    actor_loss      | -0.279   |
# |    critic_loss     | 0.0466   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 35.9     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 26       |
# |    time_elapsed    | 66       |
# |    total_timesteps | 1800     |
# | train/             |          |
# |    actor_loss      | -0.636   |
# |    critic_loss     | 0.0155   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 47.8     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 26       |
# |    time_elapsed    | 88       |
# |    total_timesteps | 2400     |
# | train/             |          |
# |    actor_loss      | -1.12    |
# |    critic_loss     | 0.0125   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 48.4     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 27       |
# |    time_elapsed    | 110      |
# |    total_timesteps | 3000     |
# | train/             |          |
# |    actor_loss      | -1.64    |
# |    critic_loss     | 0.0667   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 46.2     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 27       |
# |    time_elapsed    | 132      |
# |    total_timesteps | 3600     |
# | train/             |          |
# |    actor_loss      | -1.9     |
# |    critic_loss     | 0.0384   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 40.9     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 27       |
# |    time_elapsed    | 154      |
# |    total_timesteps | 4200     |
# | train/             |          |
# |    actor_loss      | -2.11    |
# |    critic_loss     | 0.347    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 39.3     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 27       |
# |    time_elapsed    | 176      |
# |    total_timesteps | 4800     |
# | train/             |          |
# |    actor_loss      | -2.27    |
# |    critic_loss     | 0.0704   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 35.5     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 27       |
# |    time_elapsed    | 199      |
# |    total_timesteps | 5400     |
# | train/             |          |
# |    actor_loss      | -2.82    |
# |    critic_loss     | 0.276    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 31.6     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 26       |
# |    time_elapsed    | 222      |
# |    total_timesteps | 6000     |
# | train/             |          |
# |    actor_loss      | -2.71    |
# |    critic_loss     | 0.487    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 31.2     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 26       |
# |    time_elapsed    | 248      |
# |    total_timesteps | 6600     |
# | train/             |          |
# |    actor_loss      | -2.97    |
# |    critic_loss     | 0.102    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 25.6     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 26       |
# |    time_elapsed    | 271      |
# |    total_timesteps | 7200     |
# | train/             |          |
# |    actor_loss      | -2.88    |
# |    critic_loss     | 0.111    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 23       |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 26       |
# |    time_elapsed    | 294      |
# |    total_timesteps | 7800     |
# | train/             |          |
# |    actor_loss      | -3.61    |
# |    critic_loss     | 0.0407   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 19.4     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 26       |
# |    time_elapsed    | 316      |
# |    total_timesteps | 8400     |
# | train/             |          |
# |    actor_loss      | -3.29    |
# |    critic_loss     | 0.0462   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 16.6     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 26       |
# |    time_elapsed    | 338      |
# |    total_timesteps | 9000     |
# | train/             |          |
# |    actor_loss      | -3.56    |
# |    critic_loss     | 1.74     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 13.8     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 26       |
# |    time_elapsed    | 362      |
# |    total_timesteps | 9600     |
# | train/             |          |
# |    actor_loss      | -3.41    |
# |    critic_loss     | 0.0392   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 13.4     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 26       |
# |    time_elapsed    | 385      |
# |    total_timesteps | 10200    |
# | train/             |          |
# |    actor_loss      | -3.52    |
# |    critic_loss     | 0.152    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 13       |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 26       |
# |    time_elapsed    | 408      |
# |    total_timesteps | 10800    |
# | train/             |          |
# |    actor_loss      | -3.81    |
# |    critic_loss     | 0.032    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 11       |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 26       |
# |    time_elapsed    | 437      |
# |    total_timesteps | 11400    |
# | train/             |          |
# |    actor_loss      | -3.43    |
# |    critic_loss     | 0.452    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 11.9     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 25       |
# |    time_elapsed    | 463      |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -4.18    |
# |    critic_loss     | 0.0496   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 12.2     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 25       |
# |    time_elapsed    | 487      |
# |    total_timesteps | 12600    |
# | train/             |          |
# |    actor_loss      | -4.47    |
# |    critic_loss     | 0.133    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 11.4     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 25       |
# |    time_elapsed    | 511      |
# |    total_timesteps | 13200    |
# | train/             |          |
# |    actor_loss      | -3.39    |
# |    critic_loss     | 2.23     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 10.9     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 25       |
# |    time_elapsed    | 535      |
# |    total_timesteps | 13800    |
# | train/             |          |
# |    actor_loss      | -3.67    |
# |    critic_loss     | 0.186    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 9.8      |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 25       |
# |    time_elapsed    | 559      |
# |    total_timesteps | 14400    |
# | train/             |          |
# |    actor_loss      | -3.88    |
# |    critic_loss     | 0.339    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 9.67     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 25       |
# |    time_elapsed    | 582      |
# |    total_timesteps | 15000    |
# | train/             |          |
# |    actor_loss      | -3.53    |
# |    critic_loss     | 0.104    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 6.61     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 25       |
# |    time_elapsed    | 605      |
# |    total_timesteps | 15600    |
# | train/             |          |
# |    actor_loss      | -3.66    |
# |    critic_loss     | 0.0376   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 3.35     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 25       |
# |    time_elapsed    | 628      |
# |    total_timesteps | 16200    |
# | train/             |          |
# |    actor_loss      | -3.66    |
# |    critic_loss     | 0.378    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 1.55     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 25       |
# |    time_elapsed    | 651      |
# |    total_timesteps | 16800    |
# | train/             |          |
# |    actor_loss      | -3.94    |
# |    critic_loss     | 0.0279   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | -0.399   |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 25       |
# |    time_elapsed    | 674      |
# |    total_timesteps | 17400    |
# | train/             |          |
# |    actor_loss      | -3.83    |
# |    critic_loss     | 0.0981   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 17299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | -3.78    |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 25       |
# |    time_elapsed    | 697      |
# |    total_timesteps | 18000    |
# | train/             |          |
# |    actor_loss      | -3.71    |
# |    critic_loss     | 0.237    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 17899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | -5.83    |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 25       |
# |    time_elapsed    | 720      |
# |    total_timesteps | 18600    |
# | train/             |          |
# |    actor_loss      | -3.35    |
# |    critic_loss     | 3.5      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 18499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | -6.95    |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 25       |
# |    time_elapsed    | 745      |
# |    total_timesteps | 19200    |
# | train/             |          |
# |    actor_loss      | -2.87    |
# |    critic_loss     | 0.0812   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 19099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | -7.59    |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 25       |
# |    time_elapsed    | 768      |
# |    total_timesteps | 19800    |
# | train/             |          |
# |    actor_loss      | -3.59    |
# |    critic_loss     | 0.0426   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 19699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | -5.81    |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 25       |
# |    time_elapsed    | 793      |
# |    total_timesteps | 20400    |
# | train/             |          |
# |    actor_loss      | -3.52    |
# |    critic_loss     | 0.226    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 20299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | -5.17    |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 25       |
# |    time_elapsed    | 816      |
# |    total_timesteps | 21000    |
# | train/             |          |
# |    actor_loss      | -3.16    |
# |    critic_loss     | 0.327    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 20899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | -5.79    |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 25       |
# |    time_elapsed    | 839      |
# |    total_timesteps | 21600    |
# | train/             |          |
# |    actor_loss      | -3.2     |
# |    critic_loss     | 0.112    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 21499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | -4.89    |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 25       |
# |    time_elapsed    | 862      |
# |    total_timesteps | 22200    |
# | train/             |          |
# |    actor_loss      | -3.57    |
# |    critic_loss     | 0.767    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 22099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | -3.45    |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 25       |
# |    time_elapsed    | 886      |
# |    total_timesteps | 22800    |
# | train/             |          |
# |    actor_loss      | -3.02    |
# |    critic_loss     | 1.98     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 22699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | -0.701   |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 25       |
# |    time_elapsed    | 909      |
# |    total_timesteps | 23400    |
# | train/             |          |
# |    actor_loss      | -3.14    |
# |    critic_loss     | 0.467    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 23299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 1.91     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 25       |
# |    time_elapsed    | 933      |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | -3.47    |
# |    critic_loss     | 2.23     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 23899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 1.99     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 25       |
# |    time_elapsed    | 957      |
# |    total_timesteps | 24600    |
# | train/             |          |
# |    actor_loss      | -4.88    |
# |    critic_loss     | 3.78     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 24499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 1.86     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 25       |
# |    time_elapsed    | 981      |
# |    total_timesteps | 25200    |
# | train/             |          |
# |    actor_loss      | -3.58    |
# |    critic_loss     | 2.85     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 25099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 2.3      |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 25       |
# |    time_elapsed    | 1004     |
# |    total_timesteps | 25800    |
# | train/             |          |
# |    actor_loss      | -3.88    |
# |    critic_loss     | 0.842    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 25699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 4.48     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 25       |
# |    time_elapsed    | 1028     |
# |    total_timesteps | 26400    |
# | train/             |          |
# |    actor_loss      | -4.11    |
# |    critic_loss     | 0.312    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 26299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 3.05     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 25       |
# |    time_elapsed    | 1055     |
# |    total_timesteps | 27000    |
# | train/             |          |
# |    actor_loss      | -3.98    |
# |    critic_loss     | 0.0924   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 26899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 2.05     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 25       |
# |    time_elapsed    | 1082     |
# |    total_timesteps | 27600    |
# | train/             |          |
# |    actor_loss      | -3.7     |
# |    critic_loss     | 0.0893   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 27499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 1.19     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 25       |
# |    time_elapsed    | 1104     |
# |    total_timesteps | 28200    |
# | train/             |          |
# |    actor_loss      | -3.84    |
# |    critic_loss     | 0.192    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 28099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 0.908    |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 25       |
# |    time_elapsed    | 1127     |
# |    total_timesteps | 28800    |
# | train/             |          |
# |    actor_loss      | -2.68    |
# |    critic_loss     | 4.46     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 28699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 2.37     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 25       |
# |    time_elapsed    | 1149     |
# |    total_timesteps | 29400    |
# | train/             |          |
# |    actor_loss      | -2.9     |
# |    critic_loss     | 1.37     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 29299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 2.38     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 25       |
# |    time_elapsed    | 1177     |
# |    total_timesteps | 30000    |
# | train/             |          |
# |    actor_loss      | -2.17    |
# |    critic_loss     | 0.771    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 29899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 4.84     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 25       |
# |    time_elapsed    | 1207     |
# |    total_timesteps | 30600    |
# | train/             |          |
# |    actor_loss      | -1.57    |
# |    critic_loss     | 0.17     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 30499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 5.12     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 25       |
# |    time_elapsed    | 1234     |
# |    total_timesteps | 31200    |
# | train/             |          |
# |    actor_loss      | -3.56    |
# |    critic_loss     | 0.0775   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 31099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 6.47     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 25       |
# |    time_elapsed    | 1261     |
# |    total_timesteps | 31800    |
# | train/             |          |
# |    actor_loss      | -3.3     |
# |    critic_loss     | 0.696    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 31699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 5.09     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 25       |
# |    time_elapsed    | 1289     |
# |    total_timesteps | 32400    |
# | train/             |          |
# |    actor_loss      | -3.67    |
# |    critic_loss     | 0.13     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 32299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 6.56     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 25       |
# |    time_elapsed    | 1316     |
# |    total_timesteps | 33000    |
# | train/             |          |
# |    actor_loss      | -2.09    |
# |    critic_loss     | 0.732    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 32899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 7.3      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 25       |
# |    time_elapsed    | 1342     |
# |    total_timesteps | 33600    |
# | train/             |          |
# |    actor_loss      | -2.36    |
# |    critic_loss     | 0.107    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 33499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 8.16     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 24       |
# |    time_elapsed    | 1371     |
# |    total_timesteps | 34200    |
# | train/             |          |
# |    actor_loss      | -2.17    |
# |    critic_loss     | 0.986    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 34099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 7.84     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 24       |
# |    time_elapsed    | 1398     |
# |    total_timesteps | 34800    |
# | train/             |          |
# |    actor_loss      | -2.67    |
# |    critic_loss     | 1.92     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 34699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 5.67     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 24       |
# |    time_elapsed    | 1425     |
# |    total_timesteps | 35400    |
# | train/             |          |
# |    actor_loss      | -1.94    |
# |    critic_loss     | 0.424    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 35299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 4.8      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 24       |
# |    time_elapsed    | 1450     |
# |    total_timesteps | 36000    |
# | train/             |          |
# |    actor_loss      | -2.81    |
# |    critic_loss     | 0.185    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 35899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 4.67     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 24       |
# |    time_elapsed    | 1477     |
# |    total_timesteps | 36600    |
# | train/             |          |
# |    actor_loss      | -1.43    |
# |    critic_loss     | 1.42     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 36499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 6.75     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 24       |
# |    time_elapsed    | 1503     |
# |    total_timesteps | 37200    |
# | train/             |          |
# |    actor_loss      | -1.88    |
# |    critic_loss     | 0.155    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 37099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 4.35     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 24       |
# |    time_elapsed    | 1533     |
# |    total_timesteps | 37800    |
# | train/             |          |
# |    actor_loss      | -2.02    |
# |    critic_loss     | 0.182    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 37699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 2.7      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 24       |
# |    time_elapsed    | 1559     |
# |    total_timesteps | 38400    |
# | train/             |          |
# |    actor_loss      | -2.98    |
# |    critic_loss     | 0.362    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 38299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 2.08     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 24       |
# |    time_elapsed    | 1584     |
# |    total_timesteps | 39000    |
# | train/             |          |
# |    actor_loss      | -1.96    |
# |    critic_loss     | 1.79     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 38899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 2.56     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 24       |
# |    time_elapsed    | 1610     |
# |    total_timesteps | 39600    |
# | train/             |          |
# |    actor_loss      | -2.24    |
# |    critic_loss     | 1.21     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 39499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 2.54     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 24       |
# |    time_elapsed    | 1639     |
# |    total_timesteps | 40200    |
# | train/             |          |
# |    actor_loss      | -1.71    |
# |    critic_loss     | 0.325    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 40099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 2.36     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 24       |
# |    time_elapsed    | 1673     |
# |    total_timesteps | 40800    |
# | train/             |          |
# |    actor_loss      | -1.71    |
# |    critic_loss     | 0.682    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 40699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 2.18     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 24       |
# |    time_elapsed    | 1701     |
# |    total_timesteps | 41400    |
# | train/             |          |
# |    actor_loss      | -1.41    |
# |    critic_loss     | 0.196    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 41299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 3.13     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 24       |
# |    time_elapsed    | 1731     |
# |    total_timesteps | 42000    |
# | train/             |          |
# |    actor_loss      | -2.26    |
# |    critic_loss     | 0.129    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 41899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 4.63     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 24       |
# |    time_elapsed    | 1766     |
# |    total_timesteps | 42600    |
# | train/             |          |
# |    actor_loss      | -1.97    |
# |    critic_loss     | 0.132    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 42499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 6.4      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 23       |
# |    time_elapsed    | 1800     |
# |    total_timesteps | 43200    |
# | train/             |          |
# |    actor_loss      | -1.11    |
# |    critic_loss     | 0.959    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 43099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 5.9      |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 23       |
# |    time_elapsed    | 1838     |
# |    total_timesteps | 43800    |
# | train/             |          |
# |    actor_loss      | -2.27    |
# |    critic_loss     | 1.1      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 43699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 5.14     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 23       |
# |    time_elapsed    | 1873     |
# |    total_timesteps | 44400    |
# | train/             |          |
# |    actor_loss      | -2.41    |
# |    critic_loss     | 0.268    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 44299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 5.69     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 23       |
# |    time_elapsed    | 1904     |
# |    total_timesteps | 45000    |
# | train/             |          |
# |    actor_loss      | -2.33    |
# |    critic_loss     | 0.444    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 44899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 6.23     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 23       |
# |    time_elapsed    | 1937     |
# |    total_timesteps | 45600    |
# | train/             |          |
# |    actor_loss      | -2.14    |
# |    critic_loss     | 1.05     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 45499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 6.56     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 23       |
# |    time_elapsed    | 1963     |
# |    total_timesteps | 46200    |
# | train/             |          |
# |    actor_loss      | -1.62    |
# |    critic_loss     | 0.144    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 46099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 5.91     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 23       |
# |    time_elapsed    | 1989     |
# |    total_timesteps | 46800    |
# | train/             |          |
# |    actor_loss      | -3.05    |
# |    critic_loss     | 0.218    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 46699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 10.8     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 23       |
# |    time_elapsed    | 2018     |
# |    total_timesteps | 47400    |
# | train/             |          |
# |    actor_loss      | -3.43    |
# |    critic_loss     | 0.12     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 47299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 11.1     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 23       |
# |    time_elapsed    | 2046     |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | -3.52    |
# |    critic_loss     | 0.578    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 47899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 12.1     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 23       |
# |    time_elapsed    | 2076     |
# |    total_timesteps | 48600    |
# | train/             |          |
# |    actor_loss      | -3.21    |
# |    critic_loss     | 0.449    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 48499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 11.5     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 23       |
# |    time_elapsed    | 2105     |
# |    total_timesteps | 49200    |
# | train/             |          |
# |    actor_loss      | -2.45    |
# |    critic_loss     | 1.53     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 49099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 12.4     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 23       |
# |    time_elapsed    | 2133     |
# |    total_timesteps | 49800    |
# | train/             |          |
# |    actor_loss      | -2.98    |
# |    critic_loss     | 1.44     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 49699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 11.1     |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 23       |
# |    time_elapsed    | 2162     |
# |    total_timesteps | 50400    |
# | train/             |          |
# |    actor_loss      | -2.19    |
# |    critic_loss     | 0.219    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 50299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 10.7     |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 23       |
# |    time_elapsed    | 2190     |
# |    total_timesteps | 51000    |
# | train/             |          |
# |    actor_loss      | -2.31    |
# |    critic_loss     | 1.35     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 50899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 8.85     |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 23       |
# |    time_elapsed    | 2218     |
# |    total_timesteps | 51600    |
# | train/             |          |
# |    actor_loss      | -3.71    |
# |    critic_loss     | 0.813    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 51499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 7.94     |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 23       |
# |    time_elapsed    | 2247     |
# |    total_timesteps | 52200    |
# | train/             |          |
# |    actor_loss      | -3.35    |
# |    critic_loss     | 0.88     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 52099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 9.73     |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 23       |
# |    time_elapsed    | 2279     |
# |    total_timesteps | 52800    |
# | train/             |          |
# |    actor_loss      | -3.56    |
# |    critic_loss     | 0.135    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 52699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 10       |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 23       |
# |    time_elapsed    | 2309     |
# |    total_timesteps | 53400    |
# | train/             |          |
# |    actor_loss      | -2.66    |
# |    critic_loss     | 1.94     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 53299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 9.84     |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 23       |
# |    time_elapsed    | 2336     |
# |    total_timesteps | 54000    |
# | train/             |          |
# |    actor_loss      | -3.77    |
# |    critic_loss     | 0.474    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 53899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 10.9     |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 23       |
# |    time_elapsed    | 2364     |
# |    total_timesteps | 54600    |
# | train/             |          |
# |    actor_loss      | -3.28    |
# |    critic_loss     | 0.344    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 54499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 11.7     |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 23       |
# |    time_elapsed    | 2392     |
# |    total_timesteps | 55200    |
# | train/             |          |
# |    actor_loss      | -4.55    |
# |    critic_loss     | 0.556    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 55099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 12       |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 23       |
# |    time_elapsed    | 2419     |
# |    total_timesteps | 55800    |
# | train/             |          |
# |    actor_loss      | -1.93    |
# |    critic_loss     | 0.246    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 55699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 11.1     |
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 23       |
# |    time_elapsed    | 2446     |
# |    total_timesteps | 56400    |
# | train/             |          |
# |    actor_loss      | -2.07    |
# |    critic_loss     | 0.15     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 56299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 10.1     |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 23       |
# |    time_elapsed    | 2473     |
# |    total_timesteps | 57000    |
# | train/             |          |
# |    actor_loss      | -3.05    |
# |    critic_loss     | 0.72     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 56899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 8.97     |
# | time/              |          |
# |    episodes        | 384      |
# |    fps             | 23       |
# |    time_elapsed    | 2500     |
# |    total_timesteps | 57600    |
# | train/             |          |
# |    actor_loss      | -2.85    |
# |    critic_loss     | 0.393    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 57499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 8.59     |
# | time/              |          |
# |    episodes        | 388      |
# |    fps             | 23       |
# |    time_elapsed    | 2525     |
# |    total_timesteps | 58200    |
# | train/             |          |
# |    actor_loss      | -2.73    |
# |    critic_loss     | 0.233    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 58099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 9.47     |
# | time/              |          |
# |    episodes        | 392      |
# |    fps             | 22       |
# |    time_elapsed    | 2558     |
# |    total_timesteps | 58800    |
# | train/             |          |
# |    actor_loss      | -2.37    |
# |    critic_loss     | 2.07     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 58699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 10.9     |
# | time/              |          |
# |    episodes        | 396      |
# |    fps             | 22       |
# |    time_elapsed    | 2587     |
# |    total_timesteps | 59400    |
# | train/             |          |
# |    actor_loss      | -2.69    |
# |    critic_loss     | 1.99     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 59299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 10.1     |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 22       |
# |    time_elapsed    | 2614     |
# |    total_timesteps | 60000    |
# | train/             |          |
# |    actor_loss      | -2.34    |
# |    critic_loss     | 0.319    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 59899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 9.91     |
# | time/              |          |
# |    episodes        | 404      |
# |    fps             | 22       |
# |    time_elapsed    | 2641     |
# |    total_timesteps | 60600    |
# | train/             |          |
# |    actor_loss      | -3.72    |
# |    critic_loss     | 0.561    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 60499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 8.52     |
# | time/              |          |
# |    episodes        | 408      |
# |    fps             | 22       |
# |    time_elapsed    | 2670     |
# |    total_timesteps | 61200    |
# | train/             |          |
# |    actor_loss      | -3.34    |
# |    critic_loss     | 2.33     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 61099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 11       |
# | time/              |          |
# |    episodes        | 412      |
# |    fps             | 22       |
# |    time_elapsed    | 2696     |
# |    total_timesteps | 61800    |
# | train/             |          |
# |    actor_loss      | -2.24    |
# |    critic_loss     | 1.25     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 61699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 5.47     |
# | time/              |          |
# |    episodes        | 416      |
# |    fps             | 22       |
# |    time_elapsed    | 2723     |
# |    total_timesteps | 62400    |
# | train/             |          |
# |    actor_loss      | -3.22    |
# |    critic_loss     | 0.226    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 62299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 5.35     |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 22       |
# |    time_elapsed    | 2750     |
# |    total_timesteps | 63000    |
# | train/             |          |
# |    actor_loss      | -4.14    |
# |    critic_loss     | 0.43     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 62899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 4.62     |
# | time/              |          |
# |    episodes        | 424      |
# |    fps             | 22       |
# |    time_elapsed    | 2778     |
# |    total_timesteps | 63600    |
# | train/             |          |
# |    actor_loss      | -2.86    |
# |    critic_loss     | 0.825    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 63499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 5.33     |
# | time/              |          |
# |    episodes        | 428      |
# |    fps             | 22       |
# |    time_elapsed    | 2804     |
# |    total_timesteps | 64200    |
# | train/             |          |
# |    actor_loss      | -2.84    |
# |    critic_loss     | 0.297    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 64099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 2.9      |
# | time/              |          |
# |    episodes        | 432      |
# |    fps             | 22       |
# |    time_elapsed    | 2833     |
# |    total_timesteps | 64800    |
# | train/             |          |
# |    actor_loss      | -2.84    |
# |    critic_loss     | 0.876    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 64699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 4.28     |
# | time/              |          |
# |    episodes        | 436      |
# |    fps             | 22       |
# |    time_elapsed    | 2858     |
# |    total_timesteps | 65400    |
# | train/             |          |
# |    actor_loss      | -3.62    |
# |    critic_loss     | 0.363    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 65299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 5.48     |
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 22       |
# |    time_elapsed    | 2891     |
# |    total_timesteps | 66000    |
# | train/             |          |
# |    actor_loss      | -3.63    |
# |    critic_loss     | 0.481    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 65899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 6.72     |
# | time/              |          |
# |    episodes        | 444      |
# |    fps             | 22       |
# |    time_elapsed    | 2920     |
# |    total_timesteps | 66600    |
# | train/             |          |
# |    actor_loss      | -3.21    |
# |    critic_loss     | 0.908    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 66499    |
# ---------------------------------

# %%
# Save episode info into txt file
with open('TD3_5_Episode_Info.txt', 'w') as file:
    for entry in env.episode_info:
        file.write(str(entry) + '\n\n')

# %%
# Save the TD3_5 as the best price optimization model
model.save("C:/Users/shiro/OneDrive/Desktop/Final Project OG/TD3_5")
